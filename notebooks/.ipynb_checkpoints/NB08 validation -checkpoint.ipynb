# %%
import pandas as pd
import glob
import os
#os.getcwd()
os.chdir("/home/matthew/anaconda3/envs/insight/staycationLA/data/raw")

# %%
#load data (from NB04 LA attraction reviews combine)
LA = pd.read_csv("../processed/LA_combined_reviews.csv", index_col=None)
pos=LA['stars'] > 35
pos_LA=LA[pos]
pos_LA2=pos_LA.drop(['title', 'text'], axis=1)
pos_LA2 = pos_LA2.drop_duplicates()
len(pos_LA2)
# Out:
# 126362

# %%
is_NaN = pos_LA2. isnull()
row_has_NaN = is_NaN. any(axis=1)
rows_with_NaN = pos_LA2[row_has_NaN]
pos_LA3=pos_LA2.dropna()
pos_LA3.reset_index()
len(rows_with_NaN)
# Out:
# 43

# %%
LA2=LA.drop(['stars', 'title', 'text'], axis=1)
LA3=LA2.dropna()
LA4=LA3.groupby('attraction').count()
#LA5=LA4['user'] > 1 #remove all attractions with only 1 review

# Get names of indexes for attractions with only 1 review
indexNames = LA4[ LA4['user'] == 1 ].index
# Delete these row indexes from dataFrame
LA4.drop(indexNames , inplace=True)
# Get names of indexes for attractions with only 2 review
indexNames = LA4[ LA4['user'] == 2 ].index
# Delete these row indexes from dataFrame
LA4.drop(indexNames , inplace=True)
len(LA4)
# Out:
# 1039

# %%
#read the csf (created in NB05 scrape LA reviewer travel history)
trav_hist = pd.read_csv("../processed/LA_combined_user_travel_hist.csv", index_col=None)
trav_hist = trav_hist.drop_duplicates()
len(trav_hist)
# Out:
# 3077993

# %%
LA = pd.read_csv("../processed/LA_final_corpora.csv", index_col=None)
len(LA)
# Out:
# 1335

# %%
#remove a few more weird attractions
LA = LA[~LA['attraction'].isin(['Psychiatry_An_Industry_of_Death'])]#scientology propaganda museum
LA = LA[~LA['attraction'].isin(['Foothill_Transit'])]#bus
LA = LA[~LA['attraction'].isin(['Williams_Hart_Transportation'])]#limo
LA = LA[~LA['attraction'].isin(['Union_Station'])]#transportation
LA = LA[~LA['attraction'].isin(['Museum_of_Death'])]#wierd museum
LA = LA[~LA['attraction'].isin(['WiFi_rental_around_world_Vision_Global_WiFi'])]#wierd museum
LA = LA[~LA['attraction'].isin(['Los_Angeles_Convention_Center'])]#convention center has many different events- don't want to just recommend the center itself
LA = LA[~LA['attraction'].isin(['Super_Silly_Fun_Land'])]#part of universal studios
LA = LA[~LA['type'].isin(['Visitor Centers'])]
LA = LA[~LA['type'].isin(['Rides & Activities'])]
LA = LA[~LA['type'].isin(['Arenas & Stadiums'])]
LA = LA[~LA['type'].isin(['Breweries'])]
LA = LA[~LA['type'].isin(['Distilleries'])]
LA = LA[~LA['type'].isin(['Theme Parks'])]
LA = LA[~LA['type'].isin(['Water Parks'])]

#LA = LA[~LA['type'].isin(['Shopping Malls'])]
LA_clean = LA.reset_index(drop=True)
len(LA_clean)
# Out:
# 1249

# %%
pd.options.display.max_colwidth = 20
LA_clean.head(10)
# Out:
#             attraction              english               TA_url  rating  \
# 0  Griffith_Observa...  griffith observa...  https://www.trip...     4.5
# 1    Santa_Monica_Pier  end mother road ...  https://www.trip...     4.0
# 2  Hollywood_Walk_o...  exciting crowded...  https://www.trip...     3.5
# 3     The_Getty_Center  accidentally pre...  https://www.trip...     5.0
# 4         Venice_Beach  crazy think craz...  https://www.trip...     4.0
# 5       Hollywood_Sign  beautiful landma...  https://www.trip...     4.0
# 6  Santa_Monica_Sta...  santa beach beac...  https://www.trip...     4.5
# 7          Rodeo_Drive  pretty shop supe...  https://www.trip...     4.0
# 8     Santa_Monica_Bay  wonderfully rela...  https://www.trip...     4.5
# 9  Madame_Tussauds_...  love recently vi...  https://www.trip...     4.5
#
#                    gps                  url                 type  \
# 0  [('34.118492', '...  http://www.griff...  Observatories & ...
# 1  [('34.01038', '-...  http://santamoni...  Points of Intere...
# 2  [('34.1016', '-1...  http://www.walko...  Points of Intere...
# 3  [('34.077564', '...  http://www.getty...    Specialty Museums
# 4  [('33.985912', '...  https://www.trip...              Beaches
# 5  [('34.134113', '...  http://www.visit...  Points of Intere...
# 6  [('34.0114', '-1...  http://www.smgov...          State Parks
# 7  [('34.06983', '-...  http://www.bever...  Points of Intere...
# 8  [('34.008915', '...  https://www.trip...      Bodies of Water
# 9  [('34.101566', '...  http://www.madam...    Specialty Museums
#
#                   name                  pic  num_reviews ranking
# 0  <a  href='https:...  <img class='img-...        20247      #2
# 1  <a  href='https:...  <img class='img-...        18866      #3
# 2  <a  href='https:...  <img class='img-...        17542      #4
# 3  <a  href='https:...  <img class='img-...        14503      #5
# 4  <a  href='https:...  <img class='img-...        10729      #6
# 5  <a  href='https:...  <img class='img-...         7648      #7
# 6  <a  href='https:...  <img class='img-...         6697      #8
# 7  <a  href='https:...  <img class='img-...         5491      #9
# 8  <a  href='https:...  <img class='img-...         5343     #10
# 9  <a  href='https:...  <img class='img-...         3255     #13

# %%
def top10 (cityname):
    '''
    function to calculate proportion of people who went to a city (eg Istanbul) who also left a postive (4-5 star) review on any LA attraction. This proportion ("pop_control) is then multiplied by the log total # of reviews (to weight for popularity slightly) to get a score. This score is the "right answer" which can be used to evaluate the recommender algorithm.
    '''
    city=trav_hist[trav_hist['place'].str.contains(cityname)]
    city['user'] = city['user'].astype(str)
    city_users = city['user'].tolist()
    merged_inner = pd.merge(left=pos_LA3, right=city, left_on='user', right_on='user')
    merged_inner = merged_inner.drop_duplicates()
    frame2 = merged_inner.drop(['stars', 'tag', 'place'], axis=1)
    frame2 = frame2.drop_duplicates()
    frame3 = frame2.groupby('attraction').count()
    frame4 = frame3.sort_values(by='user', ascending=False)
    merged_inner = pd.merge(left=LA4, right=frame4, left_on='attraction', right_on='attraction')
    merged_inner['pop_control']= merged_inner['user_y']/merged_inner['user_x']
    #user_y = number of people who went to the city and left a positive review, user_x = total number of people who reviewed the attraction

    import numpy as np
    merged_inner['log']= np.log((merged_inner['user_x'])+1)
    #merged_inner['log2']= np.log((merged_inner['log'])+1)
    #merged_inner['sqrt']= np.sqrt((merged_inner['user_x']))
    #merged_inner['sqrt2']= np.sqrt((merged_inner['sqrt']))

    merged_inner['score']= merged_inner['pop_control']*merged_inner['log']
    merged_inner2=merged_inner.sort_values(by='score', ascending=False)
    merged_inner3 = pd.merge(left=merged_inner2, right=LA_clean, left_on='attraction', right_on='attraction')

    return merged_inner3.head(10)
    #len(city_users)

# %%
answers = []
cities = ['Istanbul', "Beijing", 'Phuket', 'Santorini', 'Cusco', 'Sydney', 'Florence', 'Jaipur', 'Luxor', 'Marrakech', 'Rio', 'Salzburg', 'Berlin', 'Havana', 'Cape Town', "St. Petersburg", 'Edinburgh', 'Lisbon', 'Tokyo', 'Reykjavik', 'Seville', 'Addis Ababa', 'Hanoi', 'Medellin']

for cityname in cities:
    '''
    extracts "right answer" list of top 10 recommendations based on travel history and populatiry to use in model evaluation (MAP@10)
    '''
    answer = top10(cityname)
    answer_list = answer['attraction'].tolist()
    answers.append(answer_list)
    
answers
# Out:
# <ipython-input-12-661f3013e742>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city['user'] = city['user'].astype(str)
# [['Walt_Disney_Concert_Hall',
#   'Los_Angeles_County_Museum_of_Art',
#   'The_Getty_Villa',
#   'Norton_Simon_Museum',
#   'Virginia_Robinson_Gardens',
#   'The_Getty_Center',
#   'The_Huntington_Library_Art_Museum_and_Botanical_Gardens',
#   'The_Broad',
#   'Bluff_Park',
#   'Griffith_Park'],
#  ['Walt_Disney_Concert_Hall',
#   'Angelino_Heights_Historic_Area',
#   'Virginia_Robinson_Gardens',
#   'Los_Angeles_County_Museum_of_Art',
#   'The_Getty_Villa',
#   'The_Getty_Center',
#   'The_Huntington_Library_Art_Museum_and_Botanical_Gardens',
#   'Marvin_Braude_Bike_Trail',
#   'Jet_Propulsion_Laboratory',
#   'Norton_Simon_Museum'],
#  ['Odyssey_Theatre',
#   'Bluff_Park',
#   'Hillside_Memorial_Park',
#   'East_4th_Street',
#   'Pasadena_Antique_Mall',
#   'Dorothy_Chandler_Pavilion',
#   'Abalone_Cove_Beach',
#   'Historical_Society_of_Long_Beach',
#   'Belmont_Veterans_Memorial_Pier',
#   'El_Rancho_Escondido'],
#  ['Rustic_Canyon_Park',
#   'Sullivan_Canyon',
#   'Summit_Valley_Edmund_D_Edelman_Park',
#   'Mary_Hotchkiss_Park',
#   'Odyssey_Theatre',
#   'Christine_Emerson_Reed_Park',
#   'Rancho_La_Brea',
#   'El_Pescador_State_Beach',
#   'Legacy_Park',
#   'Hillside_Memorial_Park'],
#  ['Bluff_Park',
#   'Los_Angeles_Ballet',
#   'Mountain_View_Cemetery',
#   'Marciano_Art_Foundation',
#   'Walt_Disney_Concert_Hall',
#   'Vista_Hermosa_Natural_Park',
#   'Angelino_Heights_Historic_Area',
#   'The_Jazz_Bakery',
#   'Hauser_Wirth',
#   'The_Gamble_House'],
#  ['The_Getty_Villa',
#   'Walt_Disney_Concert_Hall',
#   'Mulholland_Drive',
#   '26_Mile_Bike_Path',
#   'Santa_Monica_Bay',
#   'Grand_Park',
#   'Ocean_Avenue',
#   'Griffith_Park',
#   'The_Getty_Center',
#   'Santa_Monica_State_Beach'],
#  ['The_Getty_Villa',
#   'Walt_Disney_Concert_Hall',
#   'Los_Angeles_County_Museum_of_Art',
#   'The_Getty_Center',
#   'The_Huntington_Library_Art_Museum_and_Botanical_Gardens',
#   'Norton_Simon_Museum',
#   'The_Broad_Stage',
#   'Hollywood_Bowl_Museum',
#   'The_Gamble_House',
#   'Griffith_Park'],
#  ['Old_Trapper_s_Lodge',
#   'The_Jazz_Bakery',
#   'Pasadena_City_College_Flea_Market',
#   'Odyssey_Theatre',
#   'Wat_Thai_of_Los_Angeles',
#   'Mountain_View_Cemetery',
#   'Pomona_College_Museum_of_Art',
#   'Malibu_Hindu_Temple',
#   'Walt_Disney_Concert_Hall',
#   'Beverly_Gardens_Park'],
#  ['Old_Trapper_s_Lodge',
#   'Pio_Pico_State_Historical_Park',
#   'The_Lanterman_House_Museum',
#   'Good_Shepherd_Catholic_Church',
#   'Spa_Pura',
#   'Odyssey_Theatre',
#   'A_Noise_Within_Theatre',
#   'Mountain_View_Cemetery',
#   'Valley_Relics_Museum',
#   'Largo_at_the_Coronet'],
#  ['Good_Shepherd_Catholic_Church',
#   'PAINT_LAB',
#   'The_Broad_Stage',
#   'Walt_Disney_Concert_Hall',
#   'Old_Trapper_s_Lodge',
#   'The_Huntington_Desert_Garden',
#   'The_Jazz_Bakery',
#   'Abbot_Kinney_Boulevard',
#   'The_Getty_Villa',
#   'Annenberg_Space_for_Photography'],
#  ['Ocean_Avenue',
#   'Ocean_View_Park',
#   'Griffith_Park',
#   'Hollywood_Bowl_Museum',
#   'PAINT_LAB',
#   'Mulholland_Drive',
#   'Walt_Disney_Concert_Hall',
#   'Los_Angeles_County_Museum_of_Art',
#   'The_Getty_Villa',
#   'Hollywood_Hills'],
#  ['Good_Shepherd_Catholic_Church',
#   'Walt_Disney_Concert_Hall',
#   'Queen_Anne_Cottage_and_Coach_Barn',
#   'Santa_Monica_Outdoor_Antique_Collectible_Market',
#   'Chiat_Day_Building',
#   'Beverly_Hills_City_Hall',
#   'The_Getty_Villa',
#   'Virginia_Robinson_Gardens',
#   'The_Huntington_Library_Art_Museum_and_Botanical_Gardens',
#   'Norton_Simon_Museum'],
#  ['Walt_Disney_Concert_Hall',
#   'Los_Angeles_County_Museum_of_Art',
#   'The_Broad',
#   'The_Getty_Center',
#   'The_Getty_Villa',
#   'Griffith_Park',
#   'Norton_Simon_Museum',
#   'Abbot_Kinney_Boulevard',
#   'Marvin_Braude_Bike_Trail',
#   'Santa_Monica_State_Beach'],
#  ['Zuma_and_Trancas_Canyons',
#   'Pathfinder_Community_Regional_Park',
#   'Carolyn_Campagna_Kleefeld_Contemporary_Art_Museum',
#   'Claremont_Heritage_The_Garner_House',
#   'Will_Geer_s_Theatricum_Botanicum',
#   'Los_Encinos_State_Historic_Park',
#   'The_Jazz_Bakery',
#   'The_Ebell_of_Los_Angeles',
#   'Marciano_Art_Foundation',
#   'Virginia_Avenue_Park'],
#  ['Mary_Hotchkiss_Park',
#   'Beverly_Hills_City_Hall',
#   'Little_Ethiopia',
#   'Palisades_Park_and_Recreation_Center',
#   'Walt_Disney_Concert_Hall',
#   'Marvin_Braude_Bike_Trail',
#   'El_Pueblo_de_Los_Angeles',
#   'Chiat_Day_Building',
#   'Santa_Monica_Outdoor_Antique_Collectible_Market',
#   'Sullivan_Canyon'],
#  ['Santa_Monica_Outdoor_Antique_Collectible_Market',
#   'Virginia_Robinson_Gardens',
#   'Neutra_VDL_House',
#   'Jalan_Jalan_Imports',
#   'Fine_Arts_Building',
#   'Angelus_Temple',
#   'Angelino_Heights_Historic_Area',
#   'Walt_Disney_Concert_Hall',
#   'Mount_Sinai_Memorial_Park',
#   'Los_Encinos_State_Historic_Park'],
#  ['Route_66_End_of_the_Trail_Sign',
#   'The_Getty_Villa',
#   'The_Huntington_Library_Art_Museum_and_Botanical_Gardens',
#   'Los_Angeles_Maritime_Museum',
#   'Walt_Disney_Concert_Hall',
#   'Lummis_Home_El_Alisal',
#   'Autry_Museum_of_the_American_West',
#   'Santa_Monica_State_Beach',
#   'The_Gamble_House',
#   'Griffith_Park'],
#  ['The_Getty_Villa',
#   'Walt_Disney_Concert_Hall',
#   'Los_Feliz',
#   'Abbot_Kinney_Boulevard',
#   'Eames_House',
#   'Venice_Canals_Walkway',
#   'The_Broad',
#   'Norton_Simon_Museum',
#   'Ocean_Avenue',
#   'Los_Angeles_County_Museum_of_Art'],
#  ['Walt_Disney_Concert_Hall',
#   'Japanese_American_National_Museum',
#   'Los_Angeles_County_Museum_of_Art',
#   'The_Getty_Villa',
#   'The_Getty_Center',
#   'Bradbury_Building',
#   'Angelino_Heights_Historic_Area',
#   'Belmont_Shore',
#   'Griffith_Park',
#   'Bullocks_Wilshire_Building'],
#  ['Our_Lady_Queen_of_Angels',
#   'Rustic_Canyon_Park',
#   'Old_Trapper_s_Lodge',
#   'Hop_Secret_Brewing_Company',
#   'Art_Theatre_of_Long_Beach',
#   'Zombie_Joe_s_Underground_Theatre',
#   'Museum_of_Social_Justice',
#   'Los_Encinos_State_Historic_Park',
#   'Lake_Hollywood_Park',
#   'Nicholas_Flat_Trail'],
#  ['The_Getty_Villa',
#   'Norton_Simon_Museum',
#   'Walt_Disney_Concert_Hall',
#   'Old_Plaza_Church',
#   'Art_Theatre_of_Long_Beach',
#   'Los_Angeles_County_Museum_of_Art',
#   'Virginia_Robinson_Gardens',
#   'Frederick_R_Weisman_Art_Foundation',
#   'PAINT_LAB',
#   'The_Huntington_Library_Art_Museum_and_Botanical_Gardens'],
#  ['Odyssey_Theatre',
#   'Claremont_Heritage_The_Garner_House',
#   'Covina_Center_for_the_Performing_Arts',
#   'Leimert_Park_Village',
#   'Old_Trapper_s_Lodge',
#   'Hennessey_s',
#   'Claremont_Station_Historic_1927_Santa_Fe_Depot',
#   'Route_66_End_of_the_Trail_Sign',
#   'Little_Ethiopia',
#   'County_of_Los_Angeles_Public_Library_Avalon_Branch'],
#  ['Marvin_Braude_Bike_Trail',
#   'Claremont_Heritage_The_Garner_House',
#   'Los_Encinos_State_Historic_Park',
#   'Museum_of_Social_Justice',
#   'Walt_Disney_Concert_Hall',
#   'PAINT_LAB',
#   'Pasadena_City_College_Flea_Market',
#   'Abbot_Kinney_Boulevard',
#   'Odyssey_Theatre',
#   'The_Getty_Villa'],
#  ['Tuna_Canyon_Park',
#   'Pio_Pico_State_Historical_Park',
#   'Cerritos_Farmers_Market',
#   'Pathfinder_Community_Regional_Park',
#   'Piazza_del_Sol',
#   'Santa_Monica_Outdoor_Antique_Collectible_Market',
#   'Thai_Town',
#   'Ten_Mile_Brewing_Company',
#   'Fonda_theatre',
#   'Coldwater_Canyon_Park']]

# %%
recs = []
for cityname in cities:
    '''
    extracts list of top 10 recommendations from my algorithm to use in model evaluation (MAP@10)
    '''
    rec = pd.read_csv('../cleaned/city_' + cityname + '_df.csv', index_col=None)
    rec2= rec[:10]
    new = rec2['name'].str.split(pat = "-", expand=True)
    rec_list = new[4].tolist()
    recs.append(rec_list)
    #print (new)
    
recs
# Out:
# [['Hollywood_Walk_of_Fame',
#   'Chateau_Marmont',
#   'The_Getty_Villa',
#   'Cathedral_of_Our_Lady_of_the_Angels',
#   'Downtown_Historic_District',
#   'LA_Fashion_District',
#   'Battleship_USS_Iowa_Museum',
#   'Venice_Room',
#   'Catalina_Express',
#   'The_Santee_Alley'],
#  ['Martial_Arts_History_Museum',
#   'Little_Ethiopia',
#   'Rodeo_Drive',
#   'Chinatown',
#   'LA_Fashion_District',
#   'Huy_Fong_Foods',
#   'Chinese_American_Museum',
#   'Koreatown',
#   'Mie_Pearl_Jewerly',
#   'Japanese_American_National_Museum'],
#  ['26_Mile_Bike_Path',
#   'Santa_Monica_State_Beach',
#   'Zuma_Beach',
#   'Catalina_Express',
#   'The_Sea_Caves',
#   'Manhattan_Beach',
#   'Catalina_Island_Conservancy',
#   'Redondo_Beach',
#   'Airport_in_the_Sky',
#   'Redondo_Beach_Whale_Watch'],
#  ['Catalina_Express',
#   '26_Mile_Bike_Path',
#   'Santa_Cruz_Island',
#   'Santa_Monica_State_Beach',
#   'Anacapa_Island',
#   'Zuma_Beach',
#   'The_Sea_Caves',
#   'Manhattan_Beach',
#   'Catalina_Island_Conservancy',
#   'Redondo_Beach'],
#  ['Dial_Jones_Tennis_Academy',
#   'Rodeo_Drive',
#   'LA_Fashion_District',
#   'VolleyCamp_Hermosa',
#   'The_Santee_Alley',
#   'Runyon_Canyon_Park',
#   'Eaton_Canyon',
#   'Cathedral_of_Our_Lady_of_the_Angels',
#   'Mulholland_Drive',
#   'Hollywood_Sign'],
#  ['Santa_Monica_State_Beach',
#   'Los_Angeles_Zoo_Botanical_Gardens',
#   'Santa_Cruz_Island',
#   '26_Mile_Bike_Path',
#   'Catalina_Express',
#   'Zuma_Beach',
#   'Pine_Avenue',
#   'Anacapa_Island',
#   'Colorado_Street_Bridge',
#   'Catalina_Island_Conservancy'],
#  ['Rose_Parade',
#   'Rose_Bowl_Stadium',
#   'Los_Angeles_Memorial_Coliseum',
#   'University_of_Southern_California',
#   'Norton_Simon_Museum',
#   'The_Broad',
#   'Los_Angeles_County_Museum_of_Art',
#   'Colorado_Boulevard',
#   'The_Nethercutt_Collection',
#   'The_Getty_Center'],
#  ['Malibu_Hindu_Temple',
#   'Los_Angeles_Zoo_Botanical_Gardens',
#   'Museum_of_Neon_Art',
#   'The_Gentle_Barn',
#   'Museum_of_Ice_Cream',
#   'Rodeo_Drive',
#   'Wildlife_Learning_Center',
#   'Diorama_museum_of_Bhagavad_gita',
#   'Fort_McArthur_Military_Museum',
#   'LA_Fashion_District'],
#  ['Hsi_Lai_Temple',
#   'Battleship_USS_Iowa_Museum',
#   'Wat_Thai_of_Los_Angeles',
#   'Malibu_Hindu_Temple',
#   'S_S_Lane_Victory',
#   'Thai_Town',
#   'The_Hollywood_Museum',
#   'The_Bicycle_Hotel_Casino',
#   'GRAMMY_Museum',
#   'Los_Angeles_Museum_of_the_Holocaust'],
#  ['Hsi_Lai_Temple',
#   'Wat_Thai_of_Los_Angeles',
#   'Malibu_Hindu_Temple',
#   'Chateau_Marmont',
#   'Colorado_Street_Bridge',
#   'Rodeo_Drive',
#   'Vincent_Thomas_Bridge',
#   'LA_Fashion_District',
#   'Venice_Canals_Walkway',
#   'Naples_Island'],
#  ['Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Venice_Beach',
#   'Rose_Parade',
#   '26_Mile_Bike_Path',
#   'LA_Fashion_District',
#   'Zuma_Beach',
#   'Rose_Bowl_Stadium',
#   'Venice_Beach_Boardwalk',
#   'Los_Angeles_Memorial_Coliseum'],
#  ['City_Hall',
#   'Cathedral_of_Our_Lady_of_the_Angels',
#   'Walt_Disney_Concert_Hall',
#   'The_Hollywood_Museum',
#   'City_of_Pasadena_City_Hall',
#   'GRAMMY_Museum',
#   'University_of_California_Los_Angeles_UCLA',
#   'Forest_Lawn_Memorial_Park',
#   'Downtown_Historic_District',
#   'Los_Angeles_Museum_of_the_Holocaust'],
#  ['The_Wende_Museum_of_the_Cold_War',
#   'Norton_Simon_Museum',
#   'Drum_Barracks_Civil_War_Museum',
#   'The_Broad',
#   'Beach_Boys_Monument',
#   'Sunken_City',
#   'Petersen_Automotive_Museum',
#   'The_Great_Wall_of_Los_Angeles',
#   'Autry_Museum_of_the_American_West',
#   'The_Museum_of_Contemporary_Art'],
#  ['Catalina_Island_Casino',
#   'Hsi_Lai_Temple',
#   'Wat_Thai_of_Los_Angeles',
#   'Catalina_Island_Casino_Ballroom',
#   'Malibu_Hindu_Temple',
#   'Avalon_Theater',
#   'Rodeo_Drive',
#   'The_Bicycle_Hotel_Casino',
#   'LA_Fashion_District',
#   'Old_Town_Music_Hall'],
#  ['Rodeo_Drive',
#   'Santa_Monica_State_Beach',
#   '26_Mile_Bike_Path',
#   'LA_Fashion_District',
#   'Catalina_Express',
#   'The_Santee_Alley',
#   'Zuma_Beach',
#   'Two_Rodeo_Drive',
#   'Melrose_Avenue',
#   'Santa_Cruz_Island'],
#  ['Martial_Arts_History_Museum',
#   'Little_Ethiopia',
#   'Chinese_American_Museum',
#   'Huy_Fong_Foods',
#   'Norton_Simon_Museum',
#   'Chen_Art_Gallery',
#   'Museum_of_Jurassic_Technology',
#   'Los_Angeles_County_Museum_of_Art',
#   'Mie_Pearl_Jewerly',
#   'Petersen_Automotive_Museum'],
#  ['Civic_Musical_Road',
#   'Route_138_Pearblossom_Highway',
#   'Rubel_Castle',
#   'S_S_Lane_Victory',
#   'Mulholland_Drive',
#   'GRAMMY_Museum',
#   'The_Queen_Mary',
#   'The_Hollywood_Museum',
#   'Kozy_s_Tiki_Palace',
#   'Museum_of_Jurassic_Technology'],
#  ['Civic_Musical_Road',
#   'Colorado_Street_Bridge',
#   'The_Gamble_House',
#   'Pine_Avenue',
#   'Vincent_Thomas_Bridge',
#   'Dorothy_Chandler_Pavilion',
#   'Cathedral_of_Our_Lady_of_the_Angels',
#   'The_Getty_Villa',
#   'Downtown_Historic_District',
#   'Adamson_House_and_Malibu_Lagoon_Museum'],
#  ['Little_Tokyo',
#   'Malibu_Hindu_Temple',
#   'Hsi_Lai_Temple',
#   'Chinatown',
#   'Rose_Parade',
#   'Koreatown',
#   'Wat_Thai_of_Los_Angeles',
#   'Japanese_American_National_Museum',
#   'Rodeo_Drive',
#   'El_Pueblo_de_Los_Angeles'],
#  ['Sunset_Strip',
#   'Sunset_Boulevard',
#   'Sunset_Plaza',
#   'Malibu_Lagoon_State_Beach',
#   'Catalina_Island_Conservancy',
#   nan,
#   'The_Sea_Caves',
#   'Castaic_Lake',
#   'Airport_in_the_Sky',
#   'Chateau_Marmont'],
#  ['Cathedral_of_Our_Lady_of_the_Angels',
#   'Colorado_Street_Bridge',
#   'Dorothy_Chandler_Pavilion',
#   'Our_Lady_Queen_of_Angels',
#   'Pine_Avenue',
#   'Montana_Avenue',
#   'Forest_Lawn_Memorial_Park',
#   'Vincent_Thomas_Bridge',
#   'Walt_Disney_Concert_Hall',
#   'St_Andrew_Church'],
#  ['Martial_Arts_History_Museum',
#   'Little_Ethiopia',
#   'Huy_Fong_Foods',
#   'The_Hollywood_Museum',
#   'Chinese_American_Museum',
#   'GRAMMY_Museum',
#   'Mie_Pearl_Jewerly',
#   'La_Brea_Tar_Pits_and_Museum',
#   'Chinatown',
#   'Museum_of_Tolerance'],
#  ['Venice_Canals_Walkway',
#   'Naples_Island',
#   'Abbot_Kinney_Boulevard',
#   'Montana_Avenue',
#   'Melrose_Avenue',
#   'Old_Pasadena',
#   'Belmont_Shore',
#   'Colorado_Boulevard',
#   'Rodeo_Drive',
#   'Sunset_Plaza'],
#  ['Colorado_Street_Bridge',
#   'Rose_Parade',
#   'Dorothy_Chandler_Pavilion',
#   'Rodeo_Drive',
#   'Pine_Avenue',
#   'Rose_Bowl_Stadium',
#   'Vincent_Thomas_Bridge',
#   'LA_Fashion_District',
#   'Bridge_To_Nowhere',
#   'Los_Angeles_Memorial_Coliseum']]

# %%
import ml_metrics as metrics
rec_map = metrics.mapk(answers, recs, 10)

# %%
#now compare to popularity baseline
LA_clean2= LA_clean[:10]
pop_b = LA_clean2['attraction'].tolist()
pop_list = [pop_b]*24
pop_list
# Out:
# [['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood'],
#  ['Griffith_Observatory',
#   'Santa_Monica_Pier',
#   'Hollywood_Walk_of_Fame',
#   'The_Getty_Center',
#   'Venice_Beach',
#   'Hollywood_Sign',
#   'Santa_Monica_State_Beach',
#   'Rodeo_Drive',
#   'Santa_Monica_Bay',
#   'Madame_Tussauds_Hollywood']]

# %%
pop_map = metrics.mapk(answers, pop_list, 10)

# %%
#now compare to random baseline
ran_list = []
for x in range(0, 24):
    '''
    extracts 10 random recommendations to use in model evaluation (MAP@10)
    '''
    ran10 = LA_clean.sample(n = 10) 
    ran = ran10['attraction'].tolist()
    ran_list.append(ran)
    #print (new)
    
ran_list
# Out:
# [['Route_66_End_of_the_Trail_Sign',
#   'Normandie_Casino',
#   'Odyssey_Theatre',
#   'Southern_California_Soaring_Academy',
#   'ArcLight',
#   'L_A_Louver',
#   'Skinny_House',
#   'Audubon_Center_at_Debs_Park',
#   'Hangar_18_Climbing_Gym_Southbay',
#   'Olive_Recreation_Center'],
#  ['Ten_Mile_Brewing_Company',
#   'Hauser_Wirth',
#   'Hermit_Gulch_Trail_Loop',
#   'Avila_Adobe',
#   'Theatre_West',
#   'Mrs_Fish',
#   'Peaches_and_Cream_Med_Spa',
#   'Sagebrush_Cantina',
#   'Shipmates_Sports_Bar',
#   'Westward_Beach'],
#  ['Valley_Performing_Arts_Center',
#   'Pasadena_Antique_Mall',
#   'Star_Helicopters',
#   'S_S_Lane_Victory',
#   'Palos_Verdes_Estates_Shoreline_Preserve_Beach',
#   'Wells_Fargo_Museum',
#   'Fremont_Centre_Theatre',
#   'Westward_Beach',
#   'South_Coast_Botanic_Garden',
#   'Pasadena_Museum_of_History'],
#  ['Sgt_Steve_Owen_Memorial_Park',
#   'Glendale_Presbyterian_Church',
#   'Griffith_Park_Dog_Park',
#   'Manhattan_Beach_Art_Center',
#   'King_Gillette_Ranch',
#   'Revolver_Gallery_Your_Andy_Warhol_Specialists_By_Appointment_Only',
#   'EGC_Pacific_Coast_Tours',
#   'K1_Speed_Torrance',
#   'Catalina_Island_Museum',
#   'Museum_of_Art_History_MOAH'],
#  ['Thien_Hau_Temple',
#   'Capitol_Records_Building',
#   'Echo_Mountain_Hiking_Trails',
#   'Apollo_Community_Regional_Park',
#   'California_State_University_Long_Beach',
#   'Macy_s_4th_of_July_Fireworks',
#   'Wrigley_Memorial_Botanic_Garden',
#   'Historic_Lily_pond',
#   'Leo_Carrillo_State_Park_and_Beach',
#   'Crossroads_of_the_World'],
#  ['Russian_Village_District',
#   'Henninger_Flats_Campground',
#   'Moreton_Bay_Fig_tree',
#   'Velaslavasay_Panorama',
#   'Chateau_Marmont',
#   'City_of_Pasadena_City_Hall',
#   'Muller_House_Museum',
#   'Hawthorne_Museum_Hawthorne_Historical_Society',
#   'Stahl_House',
#   'Rancho_La_Brea'],
#  ['Glendora_Mountain_Road',
#   'In_N_Out_Company_Store',
#   'Scooter_s_Jungle',
#   'Bluewater_Sailing',
#   'Venice_Canals_Walkway',
#   'Edwards_La_Verne_Stadium',
#   'Pascual_Marquez_Family_Cemetery',
#   'Lancaster_National_Soccer_Center',
#   'West_Los_Angeles_Buddhist_Temple',
#   'The_Late_Late_Show_with_Craig_Ferguson'],
#  ['Bridge_To_Nowhere',
#   'Dorothy_Green_Park',
#   'Glendale_Centre_Theatre',
#   'Santa_Monica_Public_Library',
#   'The_Unicorn_Experience',
#   'Swan_Day_Spa',
#   'Cirque_Du_Soleil_Volta',
#   'Cloverleaf_Therapeutic_Massage',
#   'Robinson_Ranch_Golf_Club',
#   'FIDM_Museum_and_Galleries'],
#  ['Malibu_Bluffs_Park',
#   'Santa_Fe_Springs_Swap_Meet',
#   'AMC_Santa_Anita_16',
#   'Site_of_77_Sunset_Strip',
#   'Doheny_Memorial_Library',
#   'Lambert_Park',
#   'Native_Visions',
#   'Theatre_West',
#   'Skirball_Cultural_Center',
#   'Downey_History_Center'],
#  ['Rustic_Canyon_Park',
#   'Catalina_Island_Museum',
#   'Andres_Pico_Adobe',
#   'Happy_Feet_Massage',
#   'Roundhouse_Marine_Studies_Lab_and_Aquarium',
#   'Edwards_Calabasas_Stadium_6',
#   'Wat_Thai_of_Los_Angeles',
#   'Paul_Smith_Los_Angeles',
#   'Dunbar_Hotel',
#   'L_A_Louver'],
#  ['Cherry_Canyon_Park',
#   'Nakatomi_Tower',
#   'Verdugo_Hills_of_Peace_Pioneer_Cemetery',
#   'Villa_Del_Sol_Sweet_Cherry_Farms',
#   'Grier_Musser_Museum',
#   'Catalina_Island_Casino_Ballroom',
#   'Olvera_Street',
#   'A_D_Architecture_and_Design_Museum',
#   'Los_Angeles_County_Fire_Museum',
#   'Echo_Park'],
#  ['Museum_of_Art_History_MOAH',
#   'Hipcooks',
#   'El_Pueblo_de_Los_Angeles',
#   'Beverly_Hills_City_Hall',
#   'Western_Museum_of_Flight',
#   'Redondo_Beach',
#   'Hollywood_La_Brea_Gateway_The_Four_Ladies_of_Hollywood_Gazebo',
#   'Ahavat_Torah_Synagogue',
#   'Playa_Del_Rey_Beach',
#   'Christine_Emerson_Reed_Park'],
#  ['Bouzy_Gastropub',
#   'Rev_Winery',
#   'Vincent_Lugo_Park',
#   'Eagle_Rock',
#   'Beverly_Hills_Public_Library',
#   'Candy_Cane_Lane',
#   'Fonda_theatre',
#   'Pasadena_Convention_Center',
#   'La_Plaza_de_Cultura_Y_Artes',
#   'Los_Angeles_Maritime_Museum'],
#  ['The_Banning_Museum',
#   'Pio_Pico_State_Historical_Park',
#   'Thai_Town',
#   'Mt_Waterman_Ski_Resort',
#   'Shrine_Auditorium_and_Expo_Hall',
#   'AMC_Norwalk_20',
#   'Paddle_House',
#   'Marina_Beach',
#   'Blvd_Farmer_s_Market',
#   'Kellogg_House_at_Cal_Poly_Pomona'],
#  ['Leonis_Adobe_Museum',
#   'Fish_Canyon_Trail',
#   'Covina_Center_for_the_Performing_Arts',
#   'Radiant_Space',
#   'Eames_House',
#   'Serenity_Park_Parrot_Sanctuary',
#   'Redondo_Beach',
#   'Wilson_Park',
#   'SEA_Lab',
#   'The_Richard_and_Karen_Carpenter_Performing_Arts_Center'],
#  ['Legg_Lake_Park_Whittier_Narrows_Recreation_Area',
#   'Pomona_College_Museum_of_Art',
#   'Starlight_Cinemas_Whittier_Village',
#   'Once_Upon_A_Time_Bookstore',
#   'Macy_s_4th_of_July_Fireworks',
#   'Drinkers_Hall_of_Fame',
#   'Lake_Balboa_Park',
#   'Casa_Adobe_De_San_Rafael_Park',
#   'Gardena_Bowling_Center',
#   'Folk_Music_Center'],
#  ['Bolton_Hall_Museum',
#   'Gehry_House',
#   'MonteVerde_Trails_Ranch',
#   'Massage_Envy_Spa',
#   'Microsoft_Theater',
#   'Santa_Monica_Pier_Aquarium',
#   'The_Reyes_Adobe_Historic_Site',
#   'Fishing_Industry_Memorial',
#   'FIDM_Museum_and_Galleries',
#   'Beverly_Canon_Gardens'],
#  ['Resin_Art_and_Photography_Gallery',
#   'Queen_Anne_Cottage_and_Coach_Barn',
#   'Ramirez_Canyon_Park',
#   'Lock_Key_Social_Drinkery',
#   'Forest_Lawn_Memorial_Park_Hollywood_Hills',
#   'Farm_Store_at_Kellogg_Ranch',
#   'Claremont_Farmers_and_Artisans_Market',
#   'Marina_del_Rey_Harbor',
#   'Thai_Town',
#   'Ocean_Trails_Reserve'],
#  ['Zuma_Beach',
#   'South_Robertson_Boulevard',
#   'Museum_of_Art_History_MOAH',
#   'Placita_de_Dolores',
#   'The_Globe_Theatre',
#   'Hollywood_Heritage_Museum',
#   'Wilderness_Park',
#   'Dolby_Theatre',
#   'Immanuel_Presbyterian_Church',
#   'Adamm_s_Stained_Glass_Art_Glass_Gallery'],
#  ['Theatre_West',
#   'Fair_Oaks_Cigars',
#   'The_Pupper_Club',
#   'Watts_Towers',
#   'Limekiln_Canyon_Park',
#   'Live_Oak_Park',
#   'Earvin_Magic_Johnson_Statue',
#   'Claremont_Museum_of_Art',
#   'Koreatown',
#   'Valencia_Laser_Blast'],
#  ['Herbie_s_Rock_Pile',
#   'Hollywood_Boulevard',
#   'Rosamund_Felsen_Gallery',
#   'Wisdome_LA',
#   'Tac_City_Airsoft',
#   'The_Oakridge_Estate',
#   'Pacifc_Theaters_Vineland_Drive_In',
#   'Angeles_National_Forest',
#   'Beach_Boys_Monument',
#   'Old_Plaza_Church'],
#  ['Otis_College_of_Art_and_Design_Gallery',
#   'Lomita_Railroad_Museum',
#   'Indian_Alley',
#   'Westlake_Golf_Course',
#   'Haugh_Performing_Center',
#   'First_United_Methodist_Church',
#   'Pio_Pico_State_Historical_Park',
#   'White_Point',
#   'AMC_Glendora_12',
#   'Long_Beach_Antique_Market'],
#  ['Square_I_Gallery',
#   'Pasadena_Convention_Center',
#   'Los_Angeles_River_Bike_Path',
#   'Playa_Del_Rey_Beach',
#   'Eaton_Canyon',
#   'Arcana_Books_on_the_Arts',
#   'Pascual_Marquez_Family_Cemetery',
#   'KP_Projects',
#   'Bruce_s_Beach',
#   'Santa_Fe_Dam_Recreation_Area'],
#  ['Mercadito',
#   'Venice_art_walls',
#   'Venice_Canals_Walkway',
#   'YouRaceLA',
#   'King_Richard_s_Antique_Center',
#   'First_United_Methodist_Church',
#   'Ten_Mile_Brewing_Company',
#   'Pedego_Electric_Bikes_RB',
#   'Sostomo_Trail',
#   'SEA_Lab']]

# %%
ran_map=metrics.mapk(answers, ran_list, 10)

# %%
import recmetrics 
#https://github.com/statisticianinstilettos/recmetrics/blob/master/example.ipynb

# %%
import matplotlib.pyplot as plt
# plot of prediction coverage
coverage_scores = [ran_map, pop_map, rec_map]
model_names = ['Random Recommender', 'Popularity Recommender', 'Topic Modeling']

fig = plt.figure(figsize=(7, 5))
recmetrics.coverage_plot(coverage_scores, model_names)

# %%
fig.savefig('../cleaned/MAP@10.png')

# %%
catalog = LA_clean.attraction.unique().tolist()
random_coverage = recmetrics.coverage(ran_list, catalog)
pop_coverage = recmetrics.coverage(pop_list, catalog)
LDA_coverage = recmetrics.coverage(recs, catalog)

# %%
# plot of prediction coverage
coverage_scores = [random_coverage, pop_coverage, LDA_coverage]
model_names = ['Random Recommender', 'Popularity Recommender', 'Topic Modeling']

fig = plt.figure(figsize=(7, 5))
recmetrics.coverage_plot(coverage_scores, model_names)

# %%
fig.savefig('../cleaned/coverage.png')

# %%
random_coverage
# Out:
# 17.92

# %%
pop_coverage
# Out:
# 0.8

# %%
LDA_coverage
# Out:
# 12.16
