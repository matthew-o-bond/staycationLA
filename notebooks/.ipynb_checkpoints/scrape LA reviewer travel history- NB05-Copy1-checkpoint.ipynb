# %%
import os
os.getcwd()
# Out:
# '/home/matthew/anaconda3/envs/insight/staycationLA/notebooks'

# %%
os.chdir('/home/matthew/anaconda3/envs/insight/staycationLA/notebooks')
os.getcwd()
# Out:
# '/home/matthew/anaconda3/envs/insight/staycationLA/notebooks'

# %%
#modified from https://github.com/giuseppegambino/Scraping-TripAdvisor-with-Python-2019/blob/master/tripadvisorSelenium.ipynb and https://stackoverflow.com/questions/53965295/selenium-beautifulsoup-python-loop-through-multiple-pages/53965437

# %%
#pip install selenium
#pip install bs4

# %%
import csv
import time
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from bs4 import BeautifulSoup
import pandas as pd 
import requests
import pickle
import re
import numpy as np

# %%
# function to check if the button is on the page, to avoid miss-click problem
def check_exists_by_xpath(xpath):
    try:
        driver.find_element_by_xpath(xpath)
    except NoSuchElementException:
        return False
    return True

# %%
def scrape(driver, user):

    if (check_exists_by_xpath("//a[contains(@class, 'ui_tab social-profile-ProfileTab__ui_tab--3f5yN') and contains(@data-tab-name, 'Travel map')]")):
        # to open travel map tab
        driver.find_element_by_xpath("//a[contains(@class, 'ui_tab social-profile-ProfileTab__ui_tab--3f5yN') and contains(@data-tab-name, 'Travel map')]").click()
        time.sleep(1)
        
        driver.switch_to.window(driver.window_handles[1])
        mapURL = (driver.current_url)
        map_source = requests.get(mapURL)
        m = re.findall('''"flags":\[([a-z, "]*?)\],"name":"(.*?)"''', map_source.text)
        n = [(tag, place, user) for (tag, place) in m]
        df = pd.DataFrame(n, columns=["tag", "place", "user"])
        df.to_csv(r'../data/raw/user_LA_' + user + '.csv', index = False, header=True)
        #df.to_csv(r'/raw/user_LA_' + user + '.csv', index = False, header=True)
        driver.close()
        driver.switch_to.window(driver.window_handles[0])
    driver.close()

# %%
#load list of usernames from NB04 LA attraction reviews combine
with open('../data/processed/userlist_final.pkl', 'rb') as f:
    usernames2 = pickle.load(f)
len(usernames2)
# Out:
# 80277

# %%
# converting list to array 
usernames3 = np.array(usernames2) 
len(usernames3)
# Out:
# 80277

# %%
#remove duplicates
names=[ x for x in usernames3 if " " not in x ]
len(names)
# Out:
# 80250

# %%
import glob
import os
os.chdir("/home/matthew/anaconda3/envs/insight/staycationLA/data/raw")
extension = 'csv'
all_users = [i for i in glob.glob('user_LA_*.{}'.format(extension))]
#print(all_users)

user_got = []

for string in all_users:
    string1 = str(string)       
    new_string = string1.replace("user_LA_", "")
    new_string2 = new_string.replace(".csv", "")
    user_got.append(new_string2)
    
user_got = list(dict.fromkeys(user_got))#remove duplicates
len(user_got)
# Out:
# 85088

# %%
import numpy as np
name_list = np.setdiff1d(names,user_got)
# yields the elements in `list_2` that are NOT in `list_1`
len(name_list)
# Out:
# 2933

# %%
name_list2=name_list.tolist()

# %%
#split list in half to run two scrapers at same time
names1 = name_list2[:len(name_list2)//2]
names2 = name_list2[len(name_list2)//2:]

# %%
#split list in half to run two scrapers at same time
names3 = names2[:len(names2)//2]
names4 = names2[len(names2)//2:]

# %%
#split list in half to run two scrapers at same time
names5 = names4[:len(names4)//2]
names6 = names4[len(names4)//2:]

# %%
len(names1)
# Out:
# 20906

# %%
print(names1)
# %%
print(names3)
# Out:
# ['Prince0786', 'PrinceRoseCroix', 'Princerman', 'PrincessA1230', 'PrincessAurora4', 'PrincessAurore', 'PrincessCK2015', 'PrincessFi88', 'PrincessStephanie01', 'Princeton1212', 'Princeton_Man', 'PriorReview', 'Prirajbhandari', 'PriscilaG396', 'PriscillaG879', 'PriscillaK93', 'PriscillaMeritello', 'PriscillaT509', 'Priscillag23', 'PrismaticCalifornia', 'Prissyboy', 'PriyaV1', 'PriyaV661', 'Priya_T', 'PriyamGopani', 'PriyankaK826', 'PriyanshBendre', 'ProHistorian', 'Problemchild2', 'Proclaimthename', 'ProfClemons', 'Professional-Pilgrim', 'Professional59', 'Professor-Zero', 'ProfessorCharles', 'ProfessorHedonism', 'ProfessorTom', 'ProfessorX69', 'Professorhosokawa', 'Proqual', 'Prothos49', 'ProudCalifNative', 'Provecho3', 'ProvocateurR', 'PrpleGrl', 'Prudence-kitten', 'PrunsM', 'PrzemyslawS402', 'Psarj', 'Pseuzyn', 'Psilber', 'Pskt52', 'Psychoanalyst', 'Ptholt', 'Ptuji', 'PublicTransitMan', 'Puddler2014', 'Puddykat', 'Puffin04', 'PuffleIreland', 'PuffoPaco', 'PuffyP12', 'PugTravel', "Pugluvin'mamma", 'Puhoidreamer', 'PukHawk', 'Pulcheri', 'Pultega4', 'PumaCalifornia', 'PumaJo', 'Pungalo2016', 'PunyS', 'PupAndCircumstance', 'Puppy_Asta', 'Puppynic', 'PurKar', 'Puravida404', 'PurdueGirl84', 'PureMiPuraVidaATL', 'Purkinji', 'PurplMyst', 'PurpleBeach5', 'PurpleHazeUK', 'PurpleLightworker', 'PurpleOneSyd', 'PurpleXD', 'Purplerain18', 'PurrGrwl', 'Purvakewlani', 'Putterking', 'Putzcat', 'PvrlGirl', 'Pyorrhea', 'Pyra-Danny', 'Pyramus_13', 'Q1150BYchristinel', 'Q1230HKstuartw', 'Q1243DSmikew', 'Q1402AHsarahm', 'Q1442JSchristopherd', 'Q1608MCsarahv', 'Q1647MHaudreyh', 'Q1842TNjoh', 'Q2016QZlisaf', 'Q2196QMclairet', 'Q2365KMpatrickk', 'Q23ZXlisag', 'Q2407IPrichardp', 'Q2465UIjohnm', 'Q2538ZHsharong', 'Q2607SMjuliah', 'Q2676MTcarolk', 'Q2749LAscottp', 'Q277TVthomasb', 'Q2896EAnatalias', 'Q2901GYelizabethg', 'Q2922WZdavidb', 'Q2SHOOT', 'Q300FOmarcob', 'Q3055EBcarolt', 'Q3057EIangelas', 'Q3066NMsamanthar', 'Q3115XVstevenl', 'Q3351ZBleeg', 'Q3434JRalexk', 'Q3449NQjessies', 'Q351VTandrewm', 'Q3817QUdaniels', 'Q3909LJterryc', 'Q3921PGbrentm', 'Q3963NXerikr', 'Q4216TTerich', 'Q4374HAelizabeths', 'Q4
ertm572', 'mrrrr5', 'mrs_hazy', 'mrsarbee', 'mrsargue86', 'mrsbanting', 'mrsbatres', 'mrsbigfamily', 'mrsblp', 'mrsbof3', 'mrsbudboden', 'mrscartagena61', 'mrscatalano', 'mrscfkeane', 'mrscichon', 'mrsdolittle', 'mrsdrotar', 'mrsez', 'mrsgiwatravels', 'mrsgoode', 'mrsguevara', 'mrshanna1', 'mrsirin', 'mrsjddrayton', 'mrskim99', 'mrsladylee', 'mrslibrarian23', 'mrsmarcoux', 'mrsmommy24', 'mrsmon2016', 'mrsnlopez', 'mrso80', 'mrsrouleau', 'mrsrushing1', 'mrstevem', 'mrstraveler35', 'mrstraveller1', 'mrsvtexas', 'mrsww3', 'mrszing', 'mrt77', 'mrterriers2', 'mrtgo', 'mrtraveltp', 'mrw71', 'mrwheels12', 'mrwunderfulness', 'mry_33', 'ms67ca', 'ms971', 'ms_karsonleigh', 'ms_swalton', 'msa23_2000', 'msadventurousone', 'msag2013', 'msarandos', 'msb16', 'msbrown5804', 'msbwashingtondc', 'msc196', 'mscaccia', 'mscanastra', 'mscheng', 'mschiffon', 'mschmidt31', 'mschref', 'mscottsedona', 'mscud1', 'mscynthiaoei', 'msdAmerInParis', 'msdebra007', 'msepiphany', 'mseren93', 'msfilipinatraveler', 'msft1', 'm ...

# %%
os.chdir('/home/matthew/anaconda3/envs/insight/staycationLA/notebooks')
os.getcwd()
# Out:
# '/home/matthew/anaconda3/envs/insight/staycationLA/notebooks'

# %%
for user in names1:
    driver = webdriver.Chrome("/home/matthew/Downloads/chromedriver")
    # insert the tripadvisor's website of one attraction 
    driver.get("https://www.tripadvisor.com/Profile/" + user)
    time.sleep(5)
    scrape(driver, user)
# Out:
# ----------------------------------------------------------
# KeyboardInterrupt        Traceback (most recent call last)
# <ipython-input-16-53bc3b581b2e> in <module>
#       4     driver.get("https://www.tripadvisor.com/Profile/" + user)
#       5     time.sleep(5)
# ----> 6     scrape(driver, user)
#
# <ipython-input-7-5bc5563944f2> in scrape(driver, user)
#       8         driver.switch_to.window(driver.window_handles[1])
#       9         mapURL = (driver.current_url)
# ---> 10         map_source = requests.get(mapURL)
#      11         m = re.findall('''"flags":\[([a-z, "]*?)\],"name":"(.*?)"''', map_source.text)
#      12         n = [(tag, place, user) for (tag, place) in m]
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     595
#     596             # Make the request on the httplib connection object.
# --> 597             httplib_response = self._make_request(conn, method, url,
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     335         context = self.ssl_context
#     336         context.verify_mode = resolve_cert_reqs(self.cert_reqs)
# --> 337         self.sock = ssl_wrap_socket(
#     338             sock=conn,
#     339             keyfile=self.key_file,
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     343             or IS_SECURETRANSPORT):
#     344         if HAS_SNI and server_hostname is not None:
# --> 345             return context.wrap_socket(sock, server_hostname=server_hostname)
#     346
#     347         warnings.warn(
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     454         while True:
#     455             try:
# --> 456                 cnx.do_handshake()
#     457             except OpenSSL.SSL.WantReadError:
#     458                 if not util.wait_for_read(sock, sock.gettimeout()):
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1931         :return: None.
#    1932         """
# -> 1933         result = _lib.SSL_do_handshake(self._ssl)
#    1934         self._raise_ssl_error(self._ssl, result)
#    1935
#
# KeyboardInterrupt:

# %%
for user in names2:
    driver = webdriver.Chrome("/home/matthew/Downloads/chromedriver")
    # insert the tripadvisor's website of one attraction 
    driver.get("https://www.tripadvisor.com/Profile/" + user)
    time.sleep(5)
    scrape(driver, user)
# Out:
# ----------------------------------------------------------
# TypeError                Traceback (most recent call last)
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt        Traceback (most recent call last)
# <ipython-input-29-f0be3e4bb298> in <module>
#       1 for user in names2:
# ----> 2     driver = webdriver.Chrome("/home/matthew/Downloads/chromedriver")
#       3     # insert the tripadvisor's website of one attraction
#       4     driver.get("https://www.tripadvisor.com/Profile/" + user)
#       5     time.sleep(5)
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      74
#      75         try:
# ---> 76             RemoteWebDriver.__init__(
#      77                 self,
#      78                 command_executor=ChromeRemoteConnection(
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in __init__(self, command_executor, desired_capabilities, browser_profile, proxy, keep_alive, file_detector, options)
#     155             warnings.warn("Please use FirefoxOptions to set browser profile",
#     156                           DeprecationWarning, stacklevel=2)
# --> 157         self.start_session(capabilities, browser_profile)
#     158         self._switch_to = SwitchTo(self)
#     159         self._mobile = Mobile(self)
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in start_session(self, capabilities, browser_profile)
#     250         parameters = {"capabilities": w3c_caps,
#     251                       "desiredCapabilities": capabilities}
# --> 252         response = self.execute(Command.NEW_SESSION, parameters)
#     253         if 'sessionId' not in response:
#     254             response = response['value']
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      68                                            **urlopen_kw)
#      69         else:
# ---> 70             return self.request_encode_body(method, url, fields=fields,
#      71                                             headers=headers,
#      72                                             **urlopen_kw)
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     148         extra_kw.update(urlopen_kw)
#     149
# --> 150         return self.urlopen(method, url, **extra_kw)
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     322             response = conn.urlopen(method, url, **kw)
#     323         else:
# --> 324             response = conn.urlopen(method, u.request_uri, **kw)
#     325
#     326         redirect_location = redirect and response.get_redirect_location()
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     595
#     596             # Make the request on the httplib connection object.
# --> 597             httplib_response = self._make_request(conn, method, url,
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/envs/insight/lib/python3.8/http/client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# ~/anaconda3/envs/insight/lib/python3.8/http/client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# ~/anaconda3/envs/insight/lib/python3.8/http/client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# ~/anaconda3/envs/insight/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
for user in names5:
    driver = webdriver.Chrome("/home/matthew/Downloads/chromedriver")
    # insert the tripadvisor's website of one attraction 
    driver.get("https://www.tripadvisor.com/Profile/" + user)
    time.sleep(5)
    scrape(driver, user)
# Out:
# ----------------------------------------------------------
# TypeError                Traceback (most recent call last)
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt        Traceback (most recent call last)
# <ipython-input-60-367fa5d409e0> in <module>
#       4     driver.get("https://www.tripadvisor.com/Profile/" + user)
#       5     time.sleep(5)
# ----> 6     scrape(driver, user)
#
# <ipython-input-25-5bc5563944f2> in scrape(driver, user)
#       7
#       8         driver.switch_to.window(driver.window_handles[1])
# ----> 9         mapURL = (driver.current_url)
#      10         map_source = requests.get(mapURL)
#      11         m = re.findall('''"flags":\[([a-z, "]*?)\],"name":"(.*?)"''', map_source.text)
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in current_url(self)
#     667             driver.current_url
#     668         """
# --> 669         return self.execute(Command.GET_CURRENT_URL)['value']
#     670
#     671     @property
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      64
#      65         if method in self._encode_url_methods:
# ---> 66             return self.request_encode_url(method, url, fields=fields,
#      67                                            headers=headers,
#      68                                            **urlopen_kw)
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/request.py in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      87             url += '?' + urlencode(fields)
#      88
# ---> 89         return self.urlopen(method, url, **extra_kw)
#      90
#      91     def request_encode_body(self, method, url, fields=None, headers=None,
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     322             response = conn.urlopen(method, url, **kw)
#     323         else:
# --> 324             response = conn.urlopen(method, u.request_uri, **kw)
#     325
#     326         redirect_location = redirect and response.get_redirect_location()
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     595
#     596             # Make the request on the httplib connection object.
# --> 597             httplib_response = self._make_request(conn, method, url,
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/envs/insight/lib/python3.8/http/client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# ~/anaconda3/envs/insight/lib/python3.8/http/client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# ~/anaconda3/envs/insight/lib/python3.8/http/client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# ~/anaconda3/envs/insight/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
for user in names6:
    driver = webdriver.Chrome("/home/matthew/Downloads/chromedriver")
    # insert the tripadvisor's website of one attraction 
    driver.get("https://www.tripadvisor.com/Profile/" + user)
    time.sleep(5)
    scrape(driver, user)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-51f9cb76d156> in <module>
#       3     # insert the tripadvisor's website of one attraction
#       4     driver.get("https://www.tripadvisor.com/Profile/" + user)
# ----> 5     time.sleep(5)
#       6     scrape(driver, user)
#
# KeyboardInterrupt:

# %%
#find last user I scraped before sending script to mehrdad
usernames2.index("ebs0303")
# Out:
# 3440

# %%
n = 3441
del usernames2[:n]
#print (usernames2)

# %%
for user in usernames2:
    # import the webdriver, chrome driver is recommended
    driver = webdriver.Chrome("/home/matthew/Downloads/chromedriver")
    # insert the tripadvisor's website of one attraction 
    driver.get("https://www.tripadvisor.com/Profile/" + user)
    time.sleep(5)
    scrape(driver)
# Out:
# ----------------------------------------------------------
# KeyboardInterrupt        Traceback (most recent call last)
# <ipython-input-149-1827d9e0e984> in <module>
#       3     driver = webdriver.Chrome("/home/matthew/Downloads/chromedriver")
#       4     # insert the tripadvisor's website of one attraction
# ----> 5     driver.get("https://www.tripadvisor.com/Profile/" + user)
#       6     time.sleep(5)
#       7     scrape(driver)
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/selenium/webdriver/remote/remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      77             )
#      78         else:
# ---> 79             return self.request_encode_body(
#      80                 method, url, fields=fields, headers=headers, **urlopen_kw
#      81             )
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     169         extra_kw.update(urlopen_kw)
#     170
# --> 171         return self.urlopen(method, url, **extra_kw)
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     334             response = conn.urlopen(method, url, **kw)
#     335         else:
# --> 336             response = conn.urlopen(method, u.request_uri, **kw)
#     337
#     338         redirect_location = redirect and response.get_redirect_location()
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     668
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#     672                 method,
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/anaconda3/envs/insight/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# ~/anaconda3/envs/insight/lib/python3.8/http/client.py in getresponse(self)
#    1330         try:
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#    1334                 self.close()
#
# ~/anaconda3/envs/insight/lib/python3.8/http/client.py in begin(self)
#     301         # read until we get a non-100 response
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#     305                 break
#
# ~/anaconda3/envs/insight/lib/python3.8/http/client.py in _read_status(self)
#     262
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#     266             raise LineTooLong("status line")
#
# ~/anaconda3/envs/insight/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
for user in usernames2:
    # import the webdriver, chrome driver is recommended
    driver = webdriver.Chrome("/home/matthew/Downloads/chromedriver")
    if "https://" in user:
        # insert the tripadvisor's website of one attraction 
        driver.get(user)
        time.sleep(5)
        scrape(driver)
    else:
        # insert the tripadvisor's website of one attraction 
        driver.get("https://www.tripadvisor.com/Profile/" + user)
        time.sleep(5)
        scrape(driver)

# %%
import glob
import os
os.chdir("/home/matthew/anaconda3/envs/insight/staycationLA/data/raw")
extension = 'csv'
all_filenames = [i for i in glob.glob('reviews_LA_usernames*.{}'.format(extension))]
#print(all_filenames)

# %%
print(all_filenames)
# Out:
# ['reviews_LA_usernamesUCLA_Marina_Aquatic_Center.csv', 'reviews_LA_usernamesUCLA_Meteorite_Gallery.csv', 'reviews_LA_usernamesYouRaceLA.csv', 'reviews_LA_usernamesWisdome_LA.csv', 'reviews_LA_usernamesLAX_Firing_Range.csv', 'reviews_LA_usernamesLA_Waterfront.csv', 'reviews_LA_usernamesPlatform_LA.csv', 'reviews_LA_usernamesShuttle_to_LAX.csv', 'reviews_LA_usernamesLAX_Theme_Building.csv', 'reviews_LA_usernamesThe_Row_DTLA.csv', 'reviews_LA_usernamesLA96C.csv', 'reviews_LA_usernamesUCLA_Athletics_Hall_of_Fame.csv', 'reviews_LA_usernamesBeautycon_LA.csv', 'reviews_LA_usernamesLA_Fashion_District.csv', 'reviews_LA_usernamesLA_Coach_Inc.csv', 'reviews_LA_usernamesOUE_Skyspace_LA.csv', 'reviews_LA_usernamesLA_Terp_Market.csv', 'reviews_LA_usernamesPAINT_LAB.csv', 'reviews_LA_usernamesLA_County_Fair.csv', 'reviews_LA_usernamesUniversity_of_California_Los_Angeles_UCLA.csv']

# %%
import glob
import os

# %%
os.chdir("/home/matthew/anaconda3/envs/insight/staycationLA/data/raw")
extension = 'csv'
all_filenames = [i for i in glob.glob('user_LA_*.{}'.format(extension))]
#print(all_filenames)

# %%
#combine all files in the list
li = []

for filename in all_filenames:
    df = pd.read_csv(filename, index_col=None)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)
frame2=frame.dropna(axis=0, how='any') #remove duplicate rows (just in case)
frame3=frame2[~frame2.place.str.contains(", USA")] #remove all domestic rows
frame4=frame3[~frame2.place.str.contains(", Canada")] 
#export to csv
frame4.to_csv( "../processed/LA_combined_user_travel_hist.csv", index=False, encoding='utf-8-sig')
# Out:
# <ipython-input-187-b4f6eb9c53fb>:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   frame4=frame3[~frame2.place.str.contains(", Canada")]

# %%
df = pd.read_csv("../processed/LA_combined_user_travel_hist.csv", index_col=None)

# %%
df2=df.drop(['tag'], axis=1)
df3=df2.groupby('place').count()
df4=df3.sort_values(by='user', ascending=False)
df4

# %%
df3=df2.groupby('place').count()

# %%
test=df2.groupby('user').count()
test.sort_values(by='place', ascending=False)
# Out:
#                   place
# user
# JillyatSea          980
# Kim1307             891
# KeithmT             865
# ochassot            832
# JamesHacon          821
# ...                 ...
# Pathfinder683720      1
# Paticu                1
# CMOMOM                1
# taminica              1
# swimmerNYC90803       1
#
# [2726 rows x 1 columns]

# %%
df4=df3.sort_values(by='user', ascending=False)

# %%
print(df4.head(20))
# Out:
#                             user
# place
# London, UK                  1567
# Paris, France               1416
# Rome, Italy                 1215
# Amsterdam, The Netherlands  1003
# Venice, Italy                970
# Barcelona, Spain             961
# Florence, Italy              791
# Dublin, Ireland              733
# Madrid, Spain                713
# Vienna, Austria              661
# Munich, Germany              653
# Milan, Italy                 643
# Sydney, Australia            631
# Berlin, Germany              626
# Prague, Czech Republic       625
# Hong Kong, China             613
# Bangkok, Thailand            610
# Edinburgh, UK                597
# Cancun, Mexico               596
# Frankfurt, Germany           580

# %%
print(df4[40:80])
# Out:
#                                  user
# place
# Seville, Spain                    416
# Bruges, Belgium                   403
# Beijing, China                    381
# Shanghai, China                   380
# Nassau, Bahamas                   379
# Playa del Carmen, Mexico          379
# Mexico City, Mexico               377
# Tijuana, Mexico                   370
# Bath, UK                          366
# Auckland Central, New Zealand     358
# Liverpool, UK                     352
# Cologne, Germany                  351
# Pisa, Italy                       347
# Buenos Aires, Argentina           347
# Cannes, France                    346
# Brisbane, Australia               330
# Cairo, Egypt                      327
# Rio de Janeiro, Brazil            326
# Hamburg, Germany                  319
# Vatican City, Vatican City        317
# Oxford, UK                        316
# Ocho Rios, Jamaica                311
# Monte-Carlo, Monaco               311
# Brighton, UK                      305
# Malaga, Spain                     303
# Geneva, Switzerland               303
# Kuala Lumpur, Malaysia            300
# Oslo, Norway                      296
# Dubrovnik, Croatia                293
# Granada, Spain                    287
# Lucerne, Switzerland              285
# Cape Town Central, South Africa   282
# New Delhi, India                  276
# Marseille, France                 275
# Jerusalem, Israel                 274
# Helsinki, Finland                 273
# Tulum, Mexico                     273
# Kyoto, Japan                      271
# Ensenada, Mexico                  271
# Marrakech, Morocco                269

# %%
print(df4.tail(10))
# Out:
#                       user
# place
# Klis, Croatia            1
# Klitmoeller, Denmark     1
# Klodzko, Poland          1
# Klovsjo, Sweden          1
# Knarvik, Norway          1
# Knighton, UK             1
# Knipoch, UK              1
# Knipton, UK              1
# Knittelfeld, Austria     1
# Limoeiro, Brazil         1

# %%
https://www.tripadvisor.com/Attraction_Review-g32954-d3474440-Reviews-Seaside_Lagoon-Redondo_Beach_California.html

# %%
https://www.tripadvisor.com/Attraction_Review-g32954-d3536275-Reviews-SEA_Lab-Redondo_Beach_California.html

# %%
https://www.tripadvisor.com/Attraction_Review-g32954-d127306-Reviews-Redondo_Beach_Pier-Redondo_Beach_California.html

# %%
https://www.tripadvisor.com/Attraction_Review-g32468-d4913474-Reviews-Hsi_Lai_Temple-Hacienda_Heights_California.html

# %%
pier = pd.read_csv("../raw/reviews_LA_Redondo_Beach_Pier.csv", index_col=None, names=['stars', 'title', 'text', 'user'])

# %%
sealab = pd.read_csv("../raw/reviews_LA_SEA_Lab.csv", index_col=None, names=['stars', 'title', 'text', 'user'])

# %%
lagoon = pd.read_csv("../raw/reviews_LA_Seaside_Lagoon.csv", index_col=None, names=['stars', 'title', 'text', 'user'])

# %%
tem = pd.read_csv("../raw/reviews_LA_Hsi_Lai_Temple.csv", index_col=None, names=['stars', 'title', 'text', 'user'])

# %%
tem2=tem.dropna(axis=0, how='any') #remove duplicate rows (just in case)

median_stars = 35

tem2.loc[tem2['stars'] > median_stars, 'review_category'] = 'Positive' 
tem2_pos = tem2[tem2['review_category'] == 'Positive']

# %%
pier2=pier.dropna(axis=0, how='any') #remove duplicate rows (just in case)

median_stars = 35

pier2.loc[pier2['stars'] > median_stars, 'review_category'] = 'Positive' 
pier2_pos = pier2[pier2['review_category'] == 'Positive']

# %%
sl2=sealab.dropna(axis=0, how='any') #remove duplicate rows (just in case)

median_stars = 35

sl2.loc[sl2['stars'] > median_stars, 'review_category'] = 'Positive' 
sl2_pos = sl2[sl2['review_category'] == 'Positive']

# %%
l2=lagoon.dropna(axis=0, how='any') #remove duplicate rows (just in case)

median_stars = 35

l2.loc[l2['stars'] > median_stars, 'review_category'] = 'Positive' 
l2_pos = l2[l2['review_category'] == 'Positive']

# %%
tem2users = tem2_pos['user'].tolist()

# %%
pier2users = pier2_pos['user'].tolist()

# %%
l2users = l2_pos['user'].tolist()

# %%
sl2users = sl2_pos['user'].tolist()

# %%
li = []

for user in sl2users:
    hist=df[df.user.str.contains(user)] 
    li.append(hist)
    
frame = pd.concat(li, axis=0, ignore_index=True)
frame2=frame.drop(['tag'], axis=1)
frame3=frame2.groupby('place').count()
frame4=frame3.sort_values(by='user', ascending=False)
frame4
# Out:
#                            user
# place
# Ixtapa, Mexico                2
# Paris, France                 2
# Acapulco, Mexico              1
# London, UK                    1
# Machu Picchu, Peru            1
# Mazatlan, Mexico              1
# Melbourne, Australia          1
# Milan, Italy                  1
# Pago Pago, American Samoa     1
# Panama City, Panama           1
# Pleiku, Vietnam               1
# Prague, Czech Republic        1
# Puerto Vallarta, Mexico       1
# Quito, Ecuador                1
# Salzburg, Austria             1
# Semarang, Indonesia           1
# Stirling, UK                  1
# Sydney, Australia             1
# Tijuana, Mexico               1
# Tokyo, Japan                  1

# %%
frame
# Out:
#        tag                      place       user
# 0   "been"    Davao City, Philippines  Judpma012
# 1   "been"              Paris, France  Judpma012
# 2   "been"  Ho Chi Minh City, Vietnam  Judpma012
# 3   "been"               Tokyo, Japan  Judpma012
# 4   "been"            Pleiku, Vietnam  Judpma012
# 5   "been"           Kinsale, Ireland     MJH048
# 6   "been"                  Hayes, UK     MJH048
# 7   "been"        Canberra, Australia     MJH048
# 8   "been"      Balikpapan, Indonesia     MJH048
# 9   "been"              Gyal, Hungary     MJH048
# 10  "been"          Debrecen, Hungary     MJH048
# 11  "been"          Budapest, Hungary     MJH048
# 12  "been"      Aguas Calientes, Peru     MJH048
# 13  "been"          Salzburg, Austria     MJH048
# 14  "been"           Acapulco, Mexico     MJH048
# 15  "been"             Ixtapa, Mexico     MJH048
# 16  "been"       Melbourne, Australia     MJH048
# 17  "been"            Cuba, Caribbean     MJH048
# 18  "been"               Havana, Cuba     MJH048
# 19  "been"          Sydney, Australia     MJH048
# 20  "been"             Varadero, Cuba     MJH048
# 21  "been"             Quito, Ecuador     MJH048
# 22  "been"               Milan, Italy     MJH048
# 23  "been"            Vienna, Austria     MJH048
# 24  "been"    Puerto Vallarta, Mexico     MJH048
# 25  "been"           Mazatlan, Mexico     MJH048
# 26  "been"               Stirling, UK     MJH048
# 27  "been"            Tijuana, Mexico     MJH048
# 28  "been"        Panama City, Panama     MJH048
# 29  "been"                  Luton, UK     MJH048
# 30  "been"           Kenmare, Ireland     MJH048
# 31  "been"            Dingle, Ireland     MJH048
# 32  "been"     Prague, Czech Republic     MJH048
# 33  "been"              Venice, Italy     MJH048
# 34  "been"                Glasgow, UK     MJH048
# 35  "been"        Liberia, Costa Rica     MJH048
# 36  "been"               Brighton, UK     MJH048
# 37  "been"         Jakarta, Indonesia     MJH048
# 38  "been"              Paris, France     MJH048
# 39  "been"            Vecses, Hungary     MJH048
# 40  "been"                Cusco, Peru     MJH048
# 41  "been"         Machu Picchu, Peru     MJH048
# 42  "been"            Dublin, Ireland     MJH048
# 43  "been"                 Lima, Peru     MJH048
# 44  "been"                 London, UK     MJH048
# 45  "been"          Kilkenny, Ireland     MJH048
# 46  "been"        Semarang, Indonesia     MJH048
# 47  "been"             Ixtapa, Mexico     MJH048
# 48  "want"  Pago Pago, American Samoa     MJH048

# %%
print(frame4.head(20))
# Out:
#                            user
# place
# Ixtapa, Mexico                2
# Paris, France                 2
# Acapulco, Mexico              1
# London, UK                    1
# Machu Picchu, Peru            1
# Mazatlan, Mexico              1
# Melbourne, Australia          1
# Milan, Italy                  1
# Pago Pago, American Samoa     1
# Panama City, Panama           1
# Pleiku, Vietnam               1
# Prague, Czech Republic        1
# Puerto Vallarta, Mexico       1
# Quito, Ecuador                1
# Salzburg, Austria             1
# Semarang, Indonesia           1
# Stirling, UK                  1
# Sydney, Australia             1
# Tijuana, Mexico               1
# Tokyo, Japan                  1

# %%
li = []

for user in l2users:
    hist=df[df.user.str.contains(user)] 
    li.append(hist)
    
frame = pd.concat(li, axis=0, ignore_index=True)
frame2=frame.drop(['tag'], axis=1)
frame3=frame2.groupby('place').count()
frame4=frame3.sort_values(by='user', ascending=False)
frame4
# Out:
#                            user
# place
# Davao City, Philippines       1
# Ho Chi Minh City, Vietnam     1
# Paris, France                 1
# Pleiku, Vietnam               1
# Tokyo, Japan                  1

# %%
li = []

for user in pier2users:
    hist=df[df.user.str.contains(user)] 
    li.append(hist)
    
frame = pd.concat(li, axis=0, ignore_index=True)
frame2=frame.drop(['tag'], axis=1)
frame3=frame2.groupby('place').count()
frame4=frame3.sort_values(by='user', ascending=False)
frame4
# Out:
#                             user
# place
# London, UK                    39
# Paris, France                 38
# Rome, Italy                   33
# Amsterdam, The Netherlands    29
# Barcelona, Spain              25
# ...                          ...
# Manapouri, New Zealand         1
# Chiapa de Corzo, Mexico        1
# Malton, UK                     1
# Chieti, Italy                  1
# Aachen, Germany                1
#
# [2979 rows x 1 columns]

# %%
print(frame4.head(20))
# Out:
#                             user
# place
# London, UK                    39
# Paris, France                 38
# Rome, Italy                   33
# Amsterdam, The Netherlands    29
# Barcelona, Spain              25
# Venice, Italy                 25
# Hong Kong, China              23
# Dublin, Ireland               23
# Vienna, Austria               22
# Tokyo, Japan                  20
# Madrid, Spain                 20
# Prague, Czech Republic        19
# Athens, Greece                19
# Cancun, Mexico                18
# Florence, Italy               18
# Munich, Germany               18
# Beijing, China                17
# Istanbul, Turkey              17
# Budapest, Hungary             16
# Milan, Italy                  16

# %%
li = []

for user in tem2users:
    hist=df[df.user.str.contains(user)] 
    li.append(hist)
    
frame = pd.concat(li, axis=0, ignore_index=True)
frame2=frame.drop(['tag'], axis=1)
frame3=frame2.groupby('place').count()
frame4=frame3.sort_values(by='user', ascending=False)
frame4
# Out:
#                             user
# place
# Amsterdam, The Netherlands     6
# Rome, Italy                    5
# Paris, France                  5
# Cancun, Mexico                 5
# Seville, Spain                 4
# ...                          ...
# Guercif, Morocco               1
# Guefait, Morocco               1
# Guatemala City, Guatemala      1
# Gros Islet, St. Lucia          1
# Lucca, Italy                   1
#
# [540 rows x 1 columns]

# %%
print(frame4.head(25))
# Out:
#                              user
# place
# Amsterdam, The Netherlands      6
# Rome, Italy                     5
# Paris, France                   5
# Cancun, Mexico                  5
# Seville, Spain                  4
# Copenhagen, Denmark             4
# Venice, Italy                   4
# Bora Bora, French Polynesia     4
# Prague, Czech Republic          4
# Barcelona, Spain                4
# Puerto Vallarta, Mexico         4
# Brussels, Belgium               4
# Shibuya, Japan                  4
# Chuo, Japan                     4
# Lisbon, Portugal                4
# Seoul, South Korea              4
# Minato, Japan                   4
# Taito, Japan                    4
# Madrid, Spain                   4
# Cabo San Lucas, Mexico          4
# Hiroshima, Japan                3
# Tulum, Mexico                   3
# Cozumel, Mexico                 3
# Tijuana, Mexico                 3
# Tokyo, Japan                    3

# %%
trav_hist = pd.read_csv("../processed/LA_combined_user_travel_hist.csv", index_col=None)
trav_hist
# Out:
#            tag                             place            user
# 0       "want"  Providenciales, Turks and Caicos  email4saundra1
# 1       "want"                  Barcelona, Spain     h2o_mermaid
# 2       "want"                       Rome, Italy     h2o_mermaid
# 3       "want"                        London, UK     h2o_mermaid
# 4       "been"                   Tijuana, Mexico     h2o_mermaid
# ...        ...                               ...             ...
# 163832  "been"                  Kathmandu, Nepal        sarsoora
# 163833  "been"                  Bophut, Thailand        sarsoora
# 163834  "been"                          York, UK      trainfan01
# 163835  "been"                        London, UK      trainfan01
# 163836  "want"                  Lisbon, Portugal        marversp
#
# [163837 rows x 3 columns]

# %%
Ist=trav_hist[trav_hist['place'].str.contains('Istanbul')]

# %%
Ist
# Out:
#                   tag             place           user
# 47             "want"  Istanbul, Turkey   CaptSunshine
# 1104           "want"  Istanbul, Turkey       Suziselt
# 1499           "been"  Istanbul, Turkey  DOCBABE_SCOUT
# 1712           "been"  Istanbul, Turkey       ddikelly
# 2096           "been"  Istanbul, Turkey      Forwarder
# ...               ...               ...            ...
# 162914         "been"  Istanbul, Turkey        siouxsy
# 163006         "been"  Istanbul, Turkey         LarryG
# 163169         "been"  Istanbul, Turkey      Gonen2014
# 163525  "been","fave"  Istanbul, Turkey      BigApple1
# 163821         "want"  Istanbul, Turkey       sarsoora
#
# [526 rows x 3 columns]

# %%
ist_users = Ist['user'].tolist()

# %%
reviews = pd.read_csv("../processed/LA_combined_reviews.csv", index_col=None)
reviews
# Out:
#        stars                                              title  \
# 0         50                  Outstanding Performing Arts Venue
# 1         50                                        Great show!
# 2         50                                  Wonderful Theater
# 3         50  An Amazing Performing Arts Center in the High ...
# 4         50                                   State of the Art
# ...      ...                                                ...
# 69255     20              Warning! Warning! Tourist Trap Ahead!
# 69256     20                                             Boring
# 69257     50                                 Great for the kids
# 69258     40                                       Good Variety
# 69259     40                                    Good production
#
#                                                     text  \
# 0      LOVE the LPAC. It is an outstanding venue for ...
# 1      We had a great time seeing a lot of different ...
# 2      We've been attending LPAC for many years for p...
# 3      The LPAC is a remarkable experience. The LPAC ...
# 4      State of the art building and equipment. World...
# ...                                                  ...
# 69255  First, know that I am a big fan of aquariums--...
# 69256  If you have been to Sea World, Boston's aquari...
# 69257  Took my 6yr old daughter there and she had the...
# 69258  This aquarium offers a nice selection of anima...
# 69259  The Theater: Small but intimate. They sell sna...
#
#                                                     user  \
# 0                                             Kathleen M
# 1                                              L. E. Cox
# 2                                              Crystal R
# 3                                               Archie M
# 4                                   DestinationLancaster
# ...                                                  ...
# 69255                                          Pennfield
# 69256                                     MelodyMontreal
# 69257                                    Experience10186
# 69258                                            LIBRA17
# 69259  https://www.tripadvisor.com/Profile/ILoveFoodComa
#
#                                 attraction
# 0      LA_Lancaster_Performing_Arts_Center
# 1      LA_Lancaster_Performing_Arts_Center
# 2      LA_Lancaster_Performing_Arts_Center
# 3      LA_Lancaster_Performing_Arts_Center
# 4      LA_Lancaster_Performing_Arts_Center
# ...                                    ...
# 69255           LA_Aquarium_of_the_Pacific
# 69256           LA_Aquarium_of_the_Pacific
# 69257           LA_Aquarium_of_the_Pacific
# 69258           LA_Aquarium_of_the_Pacific
# 69259           LA_24th_Street_Theatre_url
#
# [69260 rows x 5 columns]

# %%
li = []

for user in ist_users:
    test=pos_reviews[pos_reviews.user.str.contains(user)] 
    li.append(test)
    
frame = pd.concat(li, axis=0, ignore_index=True)
frame2=frame.drop(['text', 'title', 'stars'], axis=1)
frame3=frame2.groupby('attraction').count()
frame4=frame3.sort_values(by='user', ascending=False)
frame4.head(10)
# Out:
#                                                     user
# attraction
# LA_The_Queen_Mary                                    178
# LA_Third_Street_Promenade                            148
# LA_Santa_Monica_State_Beach                           71
# LA_Aquarium_of_the_Pacific                            64
# LA_Norton_Simon_Museum                                56
# LA_Rodeo_Drive                                        52
# LA_The_Huntington_Library_Art_Museum_and_Botani...    50
# LA_26_Mile_Bike_Path                                  35
# LA_Naples_Island                                      35
# LA_Long_Beach_Waterfront                              35

# %%
frame4
# Out:
#                                     user
# attraction
# LA_The_Queen_Mary                    178
# LA_Third_Street_Promenade            148
# LA_Santa_Monica_State_Beach           71
# LA_Aquarium_of_the_Pacific            64
# LA_Norton_Simon_Museum                56
# ...                                  ...
# LA_Industry_Hills_Golf_Club_url        1
# LA_International_City_Theatre          1
# LA_San_Antonio_Winery_url              1
# LA_Joe_Davies_Heritage_Airpark_url     1
# LA_Museum_of_Art_History_MOAH          1
#
# [220 rows x 1 columns]

# %%
reviews2=reviews.dropna(axis=0, how='any') #remove duplicate rows (just in case)
reviews2
# Out:
#        stars                                              title  \
# 0         50                  Outstanding Performing Arts Venue
# 1         50                                        Great show!
# 2         50                                  Wonderful Theater
# 3         50  An Amazing Performing Arts Center in the High ...
# 4         50                                   State of the Art
# ...      ...                                                ...
# 62399     50  A excellent collection of animals, and nice folks
# 62400     20              Warning! Warning! Tourist Trap Ahead!
# 62401     20                                             Boring
# 62402     50                                 Great for the kids
# 62403     40                                       Good Variety
#
#                                                     text  \
# 0      LOVE the LPAC. It is an outstanding venue for ...
# 1      We had a great time seeing a lot of different ...
# 2      We've been attending LPAC for many years for p...
# 3      The LPAC is a remarkable experience. The LPAC ...
# 4      State of the art building and equipment. World...
# ...                                                  ...
# 62399  I wonder, if the individual from Ohio was at a...
# 62400  First, know that I am a big fan of aquariums--...
# 62401  If you have been to Sea World, Boston's aquari...
# 62402  Took my 6yr old daughter there and she had the...
# 62403  This aquarium offers a nice selection of anima...
#
#                        user                           attraction
# 0                Kathleen M  LA_Lancaster_Performing_Arts_Center
# 1                 L. E. Cox  LA_Lancaster_Performing_Arts_Center
# 2                 Crystal R  LA_Lancaster_Performing_Arts_Center
# 3                  Archie M  LA_Lancaster_Performing_Arts_Center
# 4      DestinationLancaster  LA_Lancaster_Performing_Arts_Center
# ...                     ...                                  ...
# 62399           FarAway6039           LA_Aquarium_of_the_Pacific
# 62400             Pennfield           LA_Aquarium_of_the_Pacific
# 62401        MelodyMontreal           LA_Aquarium_of_the_Pacific
# 62402       Experience10186           LA_Aquarium_of_the_Pacific
# 62403               LIBRA17           LA_Aquarium_of_the_Pacific
#
# [62404 rows x 5 columns]

# %%
reviews['stars'] / reviews.groupby('attraction')['stars'].transform('sum')
# Out:
# 0        0.026178
# 1        0.026178
# 2        0.026178
# 3        0.026178
# 4        0.026178
#            ...
# 62399    0.000395
# 62400    0.000158
# 62401    0.000158
# 62402    0.000395
# 62403    0.000316
# Name: stars, Length: 62404, dtype: float64

# %%
reviews.groupby('attraction')['stars'].transform('sum')
# Out:
# 0          1910
# 1          1910
# 2          1910
# 3          1910
# 4          1910
#           ...
# 62399    126430
# 62400    126430
# 62401    126430
# 62402    126430
# 62403    126430
# Name: stars, Length: 62404, dtype: int64

# %%
c = reviews.groupby('attraction')['stars'].sum().rename("count")
total=c.groupby(['attraction']).sum()
maximum=(reviews.groupby('attraction')['stars'].count())*50
av=total/maximum
import numpy as np
r4=np.log(reviews3+1)
r5=np.log(r4+1)
r5a=np.log(r5+1)
r5b=np.log(r5a+1)
r5c=np.log(r5b+1)
r5d=np.log(r5c+1)
r6=np.log(r5d+1)
r6['rating']=av
r6['score']=r6['user'] * r6['rating']
r7=r6.sort_values(by='score', ascending=False)
r7.head(10)
# Out:
#                                                         user    rating  \
# attraction
# LA_The_Huntington_Library_Art_Museum_and_Botani...  0.371879  0.963305
# LA_Norton_Simon_Museum                              0.368907  0.959551
# LA_The_Getty_Center_url                             0.368513  0.955722
# LA_The_Huntington_Desert_Garden_url                 0.356654  0.977778
# LA_Glass_Church_Wayfarers_Chapel_url                0.362504  0.961798
# LA_26_Mile_Bike_Path                                0.369131  0.941138
# LA_The_Gamble_House                                 0.365217  0.943717
# LA_Frederick_R_Weisman_Art_Foundation               0.351903  0.977011
# LA_Southern_California_Soaring_Academy_url          0.349108  0.984615
# LA_Rose_Parade                                      0.358282  0.956842
#
#                                                        score
# attraction
# LA_The_Huntington_Library_Art_Museum_and_Botani...  0.358233
# LA_Norton_Simon_Museum                              0.353985
# LA_The_Getty_Center_url                             0.352197
# LA_The_Huntington_Desert_Garden_url                 0.348729
# LA_Glass_Church_Wayfarers_Chapel_url                0.348656
# LA_26_Mile_Bike_Path                                0.347404
# LA_The_Gamble_House                                 0.344662
# LA_Frederick_R_Weisman_Art_Foundation               0.343813
# LA_Southern_California_Soaring_Academy_url          0.343737
# LA_Rose_Parade                                      0.342819

# %%
c = frame.groupby('attraction')['stars'].sum().rename("count")
total=c.groupby(['attraction']).sum()
maximum=(frame.groupby('attraction')['stars'].count())*50
av=total/maximum
import numpy as np
r4=np.log(frame3+1)
r5=np.log(r4+1)
r5a=np.log(r5+1)
r5b=np.log(r5a+1)
r5c=np.log(r5b+1)
r5d=np.log(r5c+1)
r6=np.log(r5d+1)
#r6=r4
r6['rating']=av
r6['score']=r6['user'] * r6['rating']
ist_r7=r6.sort_values(by='score', ascending=False)
ist_r7.head(10)
# Out:
#                                                         user    rating  \
# attraction
# LA_The_Huntington_Library_Art_Museum_and_Botani...  0.346353  0.988000
# LA_Norton_Simon_Museum                              0.347573  0.967857
# LA_Santa_Monica_State_Beach                         0.349982  0.935211
# LA_26_Mile_Bike_Path                                0.342181  0.954286
# LA_Aquarium_of_the_Pacific                          0.348952  0.931250
# LA_Santa_Monica_Public_Library                      0.329674  0.973333
# LA_Rodeo_Drive                                      0.346780  0.919231
# LA_Naples_Island                                    0.342181  0.931429
# LA_El_Dorado_Nature_Center                          0.332738  0.955556
# LA_Third_Street_Promenade                           0.356396  0.891892
#
#                                                        score
# attraction
# LA_The_Huntington_Library_Art_Museum_and_Botani...  0.342197
# LA_Norton_Simon_Museum                              0.336401
# LA_Santa_Monica_State_Beach                         0.327307
# LA_26_Mile_Bike_Path                                0.326539
# LA_Aquarium_of_the_Pacific                          0.324961
# LA_Santa_Monica_Public_Library                      0.320883
# LA_Rodeo_Drive                                      0.318771
# LA_Naples_Island                                    0.318718
# LA_El_Dorado_Nature_Center                          0.317950
# LA_Third_Street_Promenade                           0.317867

# %%
c = frame.groupby('attraction')['stars'].sum().rename("count")
total=c.groupby(['attraction']).sum()
maximum=(frame.groupby('attraction')['stars'].count())*50
av=total/maximum
import numpy as np
r4=np.log(frame3+1)
r5=np.log(r4+1)
r5a=np.log(r5+1)
r6=np.log(r5+1)
#r6=r4
r6['rating']=av
r6['score']=r6['user'] * r6['rating']
ist_r7=r6.sort_values(by='score', ascending=False)
ist_r7.head(10)
# Out:
#                                                         user    rating  \
# attraction
# LA_The_Huntington_Library_Art_Museum_and_Botani...  0.953860  0.988000
# LA_Norton_Simon_Museum                              0.962415  0.967857
# LA_The_Queen_Mary                                   1.037628  0.883146
# LA_Santa_Monica_State_Beach                         0.979564  0.935211
# LA_Third_Street_Promenade                           1.026908  0.891892
# LA_Aquarium_of_the_Pacific                          0.972187  0.931250
# LA_26_Mile_Bike_Path                                0.925237  0.954286
# LA_Rodeo_Drive                                      0.956848  0.919231
# LA_Naples_Island                                    0.925237  0.931429
# LA_Six_Flags_Magic_Mountain                         0.912001  0.920000
#
#                                                        score
# attraction
# LA_The_Huntington_Library_Art_Museum_and_Botani...  0.942413
# LA_Norton_Simon_Museum                              0.931480
# LA_The_Queen_Mary                                   0.916377
# LA_Santa_Monica_State_Beach                         0.916099
# LA_Third_Street_Promenade                           0.915890
# LA_Aquarium_of_the_Pacific                          0.905349
# LA_26_Mile_Bike_Path                                0.882941
# LA_Rodeo_Drive                                      0.879565
# LA_Naples_Island                                    0.861793
# LA_Six_Flags_Magic_Mountain                         0.839041

# %%
r6.sort_values(by='user', ascending=False)
# Out:
#                                         user    rating     score
# attraction
# LA_The_Queen_Mary                   0.357802  0.883146  0.315991
# LA_Third_Street_Promenade           0.356396  0.891892  0.317867
# LA_Santa_Monica_State_Beach         0.349982  0.935211  0.327307
# LA_Aquarium_of_the_Pacific          0.348952  0.931250  0.324961
# LA_Norton_Simon_Museum              0.347573  0.967857  0.336401
# ...                                      ...       ...       ...
# LA_Industry_Hills_Golf_Club_url     0.234307  0.800000  0.187446
# LA_International_City_Theatre       0.234307  1.000000  0.234307
# LA_San_Antonio_Winery_url           0.234307  1.000000  0.234307
# LA_Joe_Davies_Heritage_Airpark_url  0.234307  0.800000  0.187446
# LA_Museum_of_Art_History_MOAH       0.234307  1.000000  0.234307
#
# [220 rows x 3 columns]

# %%
frame4.head(10)
# Out:
#                                                     user
# attraction
# LA_The_Queen_Mary                                    178
# LA_Third_Street_Promenade                            148
# LA_Santa_Monica_State_Beach                           71
# LA_Aquarium_of_the_Pacific                            64
# LA_Norton_Simon_Museum                                56
# LA_Rodeo_Drive                                        52
# LA_The_Huntington_Library_Art_Museum_and_Botani...    50
# LA_26_Mile_Bike_Path                                  35
# LA_Naples_Island                                      35
# LA_Long_Beach_Waterfront                              35

# %%
reviews2=reviews.drop(['text', 'title', 'stars'], axis=1)
reviews3=reviews2.groupby('attraction').count()
reviews4=reviews3.sort_values(by='user', ascending=False)
reviews4.head(10)
# Out:
#                                                     user
# attraction
# LA_Third_Street_Promenade                           4127
# LA_Santa_Monica_State_Beach                         4094
# LA_Six_Flags_Magic_Mountain                         4015
# LA_Rodeo_Drive                                      3154
# LA_Aquarium_of_the_Pacific                          2878
# LA_The_Queen_Mary                                   2709
# LA_The_Huntington_Library_Art_Museum_and_Botani...  2251
# LA_Venice_Beach_Boardwalk_url                       2050
# LA_Santa_Monica_Pier                                1374
# LA_26_Mile_Bike_Path                                1213

# %%
frame3=frame2.groupby('attraction').count()
frame4=frame3.sort_values(by='user', ascending=False)
frame4.head(10)
# Out:
#                                                     user
# attraction
# LA_The_Queen_Mary                                    250
# LA_Third_Street_Promenade                            174
# LA_Santa_Monica_State_Beach                           79
# LA_Aquarium_of_the_Pacific                            71
# LA_Rodeo_Drive                                        65
# LA_Norton_Simon_Museum                                56
# LA_The_Huntington_Library_Art_Museum_and_Botani...    51
# LA_Naples_Island                                      37
# LA_Six_Flags_Magic_Mountain                           36
# LA_Long_Beach_Waterfront                              36

# %%
options = webdriver.ChromeOptions()
#options.add_argument("start-maximized");
options.add_argument("disable-infobars")
options.add_argument("--disable-extensions")
driver = webdriver.Chrome("/home/matthew/Downloads/chromedriver", chrome_options=options)
driver.get("https://www.tripadvisor.com/Attraction_Review-g32468-d4913474-Reviews-Hsi_Lai_Temple-Hacienda_Heights_California.html")
# Out:
# <ipython-input-262-ce6d735c9f49>:5: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome("/home/matthew/Downloads/chromedriver", chrome_options=options)

# %%
l2[l2.user.str.contains("princesslollipop")]
# Out:
#     stars            title                                               text  \
# 10     50  Cold but lovely  What a wonderful place to spend a few hours wi...
#
#                 user review_category
# 10  princesslollipop        Positive

# %%
usernames3 = []

for string in usernames2:
    string1 = str(string) 
    if "https://" in string1:        
        new_string = string1.replace("https://www.tripadvisor.com/Profile/", "")
        usernames3.append(new_string)
    else:
        usernames3.append(string1)
